# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    api_key=api_key
)

print(client.api_key)
# Out:
# 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

# %% [markdown]
# ## 1. whisper: 음성 -> 텍스트로

# %%
fp = open('data/audio/베트남여행.mp3','rb')    # r(read), b:사운드,영상, 이미지

transcriptions = client.audio.transcriptions.create(model='whisper-1', file=fp)
print(transcriptions)
print(dir(transcriptions))
print(transcriptions.text)
# Out:
# Transcription(text='베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월레카드. 트래블 월레카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니 선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.', languages=None, logprobs=None, usage=UsageDuration(seconds=52.0, type='duration'))
# ...

# %% [markdown]
# 베트남여행.mp3 텍스트를 추출하고 요약하기

# %%
fp = open('data/audio/베트남여행.mp3','rb')    # r(read), b:사운드,영상, 이미지

transcription = client.audio.transcriptions.create( file=fp, model='whisper-1')
print(transcription.text)

summary = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are summarize pro"},
        {"role": "user",
         "content": f"Please summarize the following:\n{transcription.text}" }
    ]
)
print(summary.choices[0].message.content)
# Out:
# 베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월레카드. 트래블 월레카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니 선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.
# 베트남 여행 준비물 요약:
# 1. **100달러 지폐**: 큰 금액의 달러가 더 잘 환전됨.
# 2. **트래블 월레카드**: 환전 수수료 100% 우대, BP뱅크 ATM 사용 시 인출 수수료 무료.
# 3. **동지갑**: 다양한 지폐를 구분할 수 있어 편리.
# 4. **멀티템**: 보조배터리, 미니 선풍기 등 여러 전자기기를 위한 챙김.
# 5. **과도와 포크**: 망고 등 과일을 사먹을 경우 준비 (기내 반입 금지).
#
# 자세한 내용은 댓글 참조, 구독하여 여행 정보 얻기.

# %% [markdown]
# 함수정의

# %%
def transcribe_audio( file_path):
    fp = open( file_path, 'rb')
    trascription = client.audio.transcriptions.create(file=fp,
                                                      model='whisper-1')
    fp.close()
    return trascription.text

def transcribe_and_summarize( trascription_text ):
    response = client.chat.completions.create(model='gpt-4o-mini',
                messages=[
                    {'role':'system',
                        'content':'You are helpful assistant that summarizes text'},
                    {'role':'user',
                    'content':f'다음 내용을 간단히 요약해줘:\n{trascription_text}'}
                ])
    return response.choices[0].message.content


trascription_text = transcribe_audio( 'data/audio/베트남여행.mp3')
print('오디오로부터 추출된 텍스트:', trascription_text)

summarize_text = transcribe_and_summarize( trascription_text )
print( '내용:', summarize_text)
# Out:
# 오디오로부터 추출된 텍스트: 베트남 여행 준비물 30초로 정리하세요. 첫 번째, 100달러 지폐입니다. 달러 금액별로 다르게 환전해주는데 큰 금액의 달러를 더 잘 쳐줍니다. 두 번째, 트래블 월렉 카드. 트래블 월렉 카드를 이용하면 환전 수수료를 100% 우대해주고 베트남 BP뱅크 ATM을 이용하면 인출 수수료도 무료라는 사실! 바로 환전할 수 있어서 편합니다. 세 번째, 동지갑. 저는 만들기 귀찮아서 샀는데요. 워낙 지폐 종류가 많다 보니 이렇게 구분되어 있는 지갑을 가져가시는 걸 추천드립니다. 네 번째, 멀티템. 보조배터리, 미니선풍기, 휴대폰 등등등 충전할 전자기기가 너무 많죠? 멀티템 챙겨가시면 편합니다. 참고로 베트남은 대부분 220V 쓰니까 변화기는 필요 없습니다. 마지막으로 과도랑 포크. 망고 사드실 거면 챙겨가세요. 기내에는 못 들고 타는 거 아시죠? 꼭 위탁수화물에 붙이세요. 나머지는 댓글에 상세히 남겨두겠습니다. 구독하고 여행 꿀팁, 맛집 정보 받아보세요.
# 내용: 베트남 여행 준비물 요약:
#
# 1. **100달러 지폐**: 큰 금액의 환전이 더 유리함.
# 2. **트래블 월렉 카드**: 환전 수수료 면제 및 무료 인출 가능.
# 3. **동지갑**: 다양한 지폐 구분을 위한 지갑 추천.
# 4. **멀티템**: 보조배터리, 미니선풍기 등 여러 전자기기 충전용.
# 5. **과도와 포크**: 과일용으로 필요, 위탁수화물에 포함.
#
# 자세한 정보는 댓글 참조, 구독하면 추가 꿀팁 제공.

# %% [markdown]
# ## 2. tts-1 텍스트 --> 음성
# - voice 옵션 : https://platform.openai.com/docs/models/tts-1

# %%
response = client.audio.speech.create(input='안녕하세요 오늘 날씨가 참 덥네요',
                                      model="tts-1" , voice='nova' )

print(response)

# 1. 권장 방식: SDK 내장 메서드 사용
# response.write_to_file("output/out.mp3")

# 2. open() 사용 시 방식
with open('output/out.mp3', 'wb') as fp:
    fp.write(response.read())

# %% [markdown]
# 질문을 키보드입력으로 입력받고 gpt 의 답변을 음성으로 들려주기

# %%
#playsound → Colab에 외부 오디오 백엔드가 없어 실패하기 쉬움
#!uv add playsound==1.2.2
#IPython.display.Audio → Colab/노트북 환경에서 가장 호환성이 좋고 간단한 재생 방법

# %% [markdown]
# uv add playsound==1.2.2

# %%
from openai import OpenAI
from playsound import playsound
from IPython.display import Audio
# from google.colab import userdata



prompt = input('prompt: ')

response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {'role': 'user', 'content': prompt}
    ]
)
resp = response.choices[0].message.content
print( 'gpt',resp )

response_to_voice = client.audio.speech.create(input=resp, model='tts-1',voice='nova')
with open('output/sound2.mp3', 'wb') as fp: #'wb(write binary) 모드로 파일을 열어야함'
    fp.write(response_to_voice.content)

Audio('output/sound2.mp3', autoplay=True)
# Out:
# gpt 안녕하세요! 어떻게 도와드릴까요?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 3. dall-e-3 이미지 생성

# %%
#!uv add requests

# %% [markdown]
# DALL-E 3 모델을 API로 호출하려면 OpenAI 계정이 유료 결제 계정(Usage Tier 1 이상)이어야 합니다.
#
# 무료 평가판(Free Trial) 계정이나 결제 수단만 등록되어 있고 최소 충전 금액($5 이상)을 결제하지 않은 계정은 dall-e-3 권한이 부여되지 않습니다.

# %%
from openai import OpenAI
import requests

# dall-e-2 : 편집모델, dall-e-3: 생성모델

#  이미지 생성 요청
response = client.images.generate(
    prompt="a white siamese cat",
    model="gpt-image-2",
    size="1024x1024",
    quality="standard",
    n=1,
)

#  이미지 URL 추출
image_url = response.data[0].url
print("Image URL:", image_url)

#  이미지 다운로드 및 저장 (DALL-E 3 기본 포맷인 png 확장자 권장)
image_data = requests.get(image_url).content
with open("output/genimage.png", "wb") as fp:
    fp.write(image_data)

print("이미지가 output/genimage.png 경로에 성공적으로 저장되었습니다.")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\sk-encoa\llm-workspace\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3823, in run_code
#   File "C:\Users\playdata2\AppData\Local\Temp\ipykernel_12508\1517421303.py", line 9, in <module>
#     response = client.images.generate(
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sk-encoa\llm-workspace\.venv\Lib\site-packages\openai\_utils\_utils.py", line 298, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\sk-encoa\llm-workspace\.venv\Lib\site-packages\openai\resources\images.py", line 1012, in generate
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\sk-encoa\llm-workspace\.venv\Lib\site-packages\openai\_base_client.py", line 1368, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
# ...

# %%
from openai import OpenAI
import requests


# dall-e-2 : 편집모델, dall-e-3: 생성모델
response = client.images.generate(prompt='20대 여성이 한복을 입고 있는 모습',
                         model="dall-e-3",
                         size="1024x1024",
                          quality="standard" ,n=1 )
print(response)
print(response.data[0].url )
image_url = response.data[0].url
image_data =  requests.get( image_url ).content
with open('output/genimage.jpg','wb') as fp:
    fp.write( image_data)
# Out:
# ImagesResponse(created=1756948088, background=None, data=[Image(b64_json=None, revised_prompt="A young woman in her 20s wearing a traditional Korean Hanbok. The woman has delicate features, a gentle smile on her face, and her hair styled in a neat bun. The Hanbok she is wearing is colorfully embroidered, featuring bright hues of pink and green, and her full skirt flows gracefully down. The woman's expression and outfit together exude an air of timeless elegance and cultural pride.", url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-LZOe8m0W7QQbswkOMsfxsl4M/user-zxlj0hIAsKZt2NUpktkXJnlz/img-gGuX0O56BCeuqQALcV8r9On2.png?st=2025-09-04T00%3A08%3A08Z&se=2025-09-04T02%3A08%3A08Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=ed3ea2f9-5e38-44be-9a1b-7c1e65e4d54f&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-09-03T18%3A24%3A40Z&ske=2025-09-04T18%3A24%3A40Z&sks=b&skv=2024-08-04&sig=wYQEHvcoz8iUBYGlmKSo9L7Jzd4UFfFG7jAbqU5f/3E%3D')], output_format=None, quality=
# ...

# %% [markdown]
# ## 4. dall-e-2 이미지 편집

# %%
from openai import OpenAI
from urllib import response

import requests



# sunlit.png에 mask3.png에서 마스크된곳 물고기를 그린다.
response=client.images.edit(model="dall-e-2",
                           image=open("data/image/sunlit.png",'rb'),
                           mask=open("data/image/mask3.png",'rb'),
                           prompt="A sunlit indoor lounge area with a a pool containing a fish",
                           n=2,
                           size="1024x1024")
print(response.data[0].url)
print(response.data[1].url)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 9
#       5
#       6
#       7
#       8 # sunlit.png에 mask3.png에서 마스크된곳 물고기를 그린다.
# ----> 9 response=client.images.edit(model="dall-e-2",
#      10                            image=open("data/image/sunlit.png",'rb'),
#      11                            mask=open("data/image/mask3.png",'rb'),
#      12                            prompt="A sunlit indoor lounge area with a a pool containing a fish",
#
# File c:\sk-encoa\llm-workspace\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
from openai import OpenAI
from urllib import response
import requests




# sunlit.png에 mask3.png에서 마스크된곳 물고기를 그린다.
response=client.images.edit(model="dall-e-2",
                           image=open("data/image/sunlit.png",'rb'),
                           mask=open("data/image/mask3.png",'rb'),
                            prompt=(
        "Sunlit indoor lounge with a small tiled pool. Crystal-clear water with gentle ripples, "
        "sharp caustic light patterns on the pool floor, realistic window reflections on the surface, "
        "wet glossy tiles and subtle droplets around the edge. One koi fish near the surface (single fish). "
        "Ultra photorealistic architectural photograph, 35mm, f/5.6, global illumination, HDR. "
        "No text, no people, no cartoon style."
    ),
                           n=2,
                           size="1024x1024")
print(response.data[0].url)
print(response.data[1].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-LZOe8m0W7QQbswkOMsfxsl4M/user-zxlj0hIAsKZt2NUpktkXJnlz/img-ZeglGHy0XC8r6YXrbJqy9Xhj.png?st=2025-09-04T00%3A16%3A47Z&se=2025-09-04T02%3A16%3A47Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=b1a0ae1f-618f-4548-84fd-8b16cacd5485&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-09-03T13%3A58%3A06Z&ske=2025-09-04T13%3A58%3A06Z&sks=b&skv=2024-08-04&sig=nD2arNR4v4fUw0%2BL6WazNujlOVArFbDQHPYKdcyA/wY%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-LZOe8m0W7QQbswkOMsfxsl4M/user-zxlj0hIAsKZt2NUpktkXJnlz/img-l8xkA3SlP4g7ghJaOPI0bUW7.png?st=2025-09-04T00%3A16%3A46Z&se=2025-09-04T02%3A16%3A46Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=b1a0ae1f-618f-4548-84fd-8b16cacd5485&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-09-03T13%3A58%3A06Z&ske=2025-09-04T13%3A58%3A06Z&sks=b&skv=2024-08-04&sig=8xLRvsnyiKXHC/OboG/8tEAzG4WI/FMr5lpmSTEY3xI%3D

# %% [markdown]
# ## 5. 음성을 wav 파일로 저장
# - 5초 녹음 → webm 저장 → ffmpeg로 16kHz mono WAV 변환 → 자동 재생)
# - 브라우저 MediaRecorder는 보통 audio/webm이 표준이므로 그걸로 녹음하고, 나중에 ffmpeg로 WAV 변환합니다.
#
# - 파일명을 헷갈리지 않게: 녹음 파일은 /content/rec.webm, 변환본은 /content/rec.wav로 분리했습니다.

# %% [markdown]
# Colab 전용: 브라우저 마이크로 녹음해 rec.wav 만들기

# %%
# 0) 필요한 도구 설치 (ffmpeg 변환용)
# !apt -y install ffmpeg > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %% [markdown]
# ```
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# ```
#
# Colab에서 apt 쓸 때 자주 뜨는 안내문이라 무시해도 괜찮아요. 설치 상태만 확인해 주세요.

# %%
# (2) 브라우저 마이크로 N초 녹음 → /content/rec.webm 저장

import base64

def record_to_webm(seconds=5, path="/content/rec.webm"):
    js = f"""
    (async () => {{
      const sleep = ms => new Promise(r => setTimeout(r, ms));
      const b2text = blob => new Promise((resolve, reject) => {{
        const reader = new FileReader();
        reader.onloadend = () => resolve(reader.result);
        reader.onerror = reject;
        reader.readAsDataURL(blob);
      }});
      const stream = await navigator.mediaDevices.getUserMedia({{ audio: true }});
      const rec = new MediaRecorder(stream, {{ mimeType: 'audio/webm' }});
      const chunks = [];
      rec.ondataavailable = e => chunks.push(e.data);
      rec.start();
      await sleep({int(seconds*1000)});
      rec.stop();
      await new Promise(res => rec.onstop = res);
      stream.getTracks().forEach(t => t.stop());
      const blob = new Blob(chunks, {{ type: 'audio/webm' }});
      return await b2text(blob);   // data: URL (base64) 반환
    }})()
    """
    b64 = output.eval_js(js)
    data = base64.b64decode(b64.split(",")[1])
    with open(path, "wb") as f:
        f.write(data)
    return path

webm_path = record_to_webm(seconds=5, path="output/rec.webm")
print("Saved:", webm_path)
# Out:
# Saved: /content/rec.webm

# %%
# (3) webm → 16kHz mono WAV 변환 (STT/TTS 등에 적합)
# !ffmpeg -y -i /content/rec.webm -ar 16000 -ac 1 /content/rec.wav -loglevel error
print("WAV saved: /content/rec.wav")

# (4) 자동 재생
from IPython.display import Audio, display
display(Audio('/content/rec.wav', autoplay=True))
# Out:
# WAV saved: /content/rec.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 3) Colab에서 바로 자동 재생
from IPython.display import Audio, display
display(Audio('/content/rec.wav', autoplay=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 3) Colab에서 바로 자동 재생
#       2 from IPython.display import Audio, display
# ----> 3 display(Audio('/content/rec.wav', autoplay=True))
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %% [markdown]
# local 전용: 브라우저 마이크로 녹음해 rec.wav 만들기

# %% [markdown]
# ## 6. 음성으로 gpt에게 명령하고 음성으로 답변을 재생하시오.

# %% [markdown]
# colab에서 실행

# %%
#!apt-get -qq update
#!apt-get -qq install -y ffmpeg
#!pip -q install openai

# %%
from openai import OpenAI
from IPython.display import Audio, display
import base64, os, subprocess
from dotenv import load_dotenv
import os



# 1) OpenAI API 초기화
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
assert OPENAI_API_KEY, "OPENAI_API_KEY가 설정되어 있어야 합니다."
client = OpenAI(api_key=OPENAI_API_KEY)

# 2) 브라우저 마이크로 N초 녹음 → /content/rec.webm 저장
def record_to_webm(seconds=5, path="/content/rec.webm"):
 
    b64 = output.eval_js(js)
    data = base64.b64decode(b64.split(",")[1])
    with open(path, "wb") as f:
        f.write(data)
    return path

# 3) webm → 16kHz mono WAV 변환 (Whisper 친화 형식)
def webm_to_wav(webm_path="/content/rec.webm", wav_path="/content/rec.wav"):
    subprocess.run(
        ["ffmpeg", "-y", "-i", webm_path, "-ar", "16000", "-ac", "1", wav_path],
        check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE
    )
    return wav_path

# 4) STT (Whisper) — 한국어 고정
def transcribe_audio(file_path):
    with open(file_path, "rb") as fp:
        tr = client.audio.transcriptions.create(
            model="whisper-1",
            file=fp,
            language="ko"      # ✅ 한국어 강제
            # temperature=0.0, # (선택) 더 보수적으로 인식
        )
    return tr.text.strip()

# 5) GPT 질의 — 한국어 응답 강제
def ask_gpt(prompt_text):
    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role":"system","content":"항상 한국어(존댓말)로 자연스럽고 간결하게 답변하세요. 필요한 경우만 1~2문장 추가 설명을 덧붙이세요."},
            {"role":"user","content": prompt_text}
        ]
    )
    return resp.choices[0].message.content.strip()

# 6) TTS (mp3 생성) + 자동 재생
def speak_text(text, output_file="/content/out.mp3"):
    speech = client.audio.speech.create(
        model="tts-1",
        voice="nova",
        input=text
    )
    with open(output_file, "wb") as f:
        f.write(speech.content)
    print("음성 파일 생성:", output_file)
    display(Audio(output_file, autoplay=True))

# 7) 전체 파이프라인
def main(duration_sec=5):
    print("▶ 브라우저 마이크 녹음 시작… (권한 허용 필요)")
    webm = record_to_webm(seconds=duration_sec, path="/content/rec.webm")
    wav = webm_to_wav(webm, "/content/rec.wav")
    print("녹음/변환 완료:", wav)

    question = transcribe_audio(wav)
    print("[STT] 질문 내용:", question)

    answer = ask_gpt(question)
    print("[GPT] 답변 내용:", answer)

    speak_text(answer, "/content/out.mp3")

# 실행
main(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 from openai import OpenAI
#       2 from IPython.display import Audio, display
#       3 import base64, os, subprocess
# ----> 4 from google.colab import userdata
#       5
#       6 # 1) OpenAI API 초기화
#       7 OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# local에서 실행

# %%
#! uv add sounddevice scipy pygame

# %%
import os
import time
from openai import OpenAI
import pygame
from scipy.io.wavfile import write
import sounddevice as sd

client = OpenAI()

OUTPUT_DIR = "output"
os.makedirs(OUTPUT_DIR, exist_ok=True)


# 1. 안전한 MP3 재생 함수 (파일 잠금 완벽 해제)
def playmp3(output_file):
    print("🔊 답변 음성 재생 중...")
    pygame.mixer.init()
    pygame.mixer.music.load(output_file)
    pygame.mixer.music.play()

    while pygame.mixer.music.get_busy():
        time.sleep(0.1)

    # [핵심] 재생 완료 후 트랙 언로드 및 믹서 종료 (파일 잠금 해제)
    pygame.mixer.music.unload()
    pygame.mixer.quit()


# 2. TTS 변환 및 저장 함수 (타임스탬프 활용으로 파일 충돌 방지)
def speak_text(text):
    print("🗣️ 텍스트를 음성으로 변환 중 (TTS)...")

    # 충돌 방지를 위해 실행 시점의 타임스탬프로 파일명 생성
    filename = f"{OUTPUT_DIR}/out_{int(time.time())}.mp3"

    response = client.audio.speech.create(
        model="tts-1", voice="nova", input=text
    )

    # 최신 SDK 방식 파일 쓰기
    response.write_to_file(filename)
    print("✅ 음성 파일 생성 완료:", filename)

    # 재생
    playmp3(filename)


# 3. 음성 인식(STT) 예외 처리 보완
def transcribe_audio(file_path):
    print("🔍 음성을 텍스트로 변환하는 중 (STT)...")
    with open(file_path, "rb") as fp:
        transcription = client.audio.transcriptions.create(
            file=fp, model="whisper-1"
        )

    text = transcription.text.strip()

    # [.], [?] 등 단일 특수문자만 들어온 경우 빈 문자열로 처리
    if text in [".", "?", "!", ""]:
        return ""

    return text


def record_audio(
    filename=f"{OUTPUT_DIR}/recorded.wav", duration=5, fs=16000
):
    print("🎤 음성 녹음을 시작합니다... (5초간 말씀하세요)")
    audio_data = sd.rec(int(duration * fs), samplerate=fs, channels=1)
    sd.wait()

    audio_int16 = (audio_data * 32767).astype("int16")
    write(filename, fs, audio_int16)
    print("✅ 녹음 완료:", filename)
    return filename


def ask_gpt(prompt_text):
    print("🤖 GPT 답변 생성 중...")
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "당신은 친절한 20대 여성 AI 비서입니다."},
            {"role": "user", "content": prompt_text},
        ],
    )
    return response.choices[0].message.content.strip()


def main():
    try:
        audio_file = record_audio(duration=5)

        question_text = transcribe_audio(audio_file)
        print(f"\n[사용자 질문]: {question_text}")

        # 음성 입력이 없거나 감지되지 않은 경우 거부
        if not question_text:
            print("⚠️ 음성이 제대로 감지되지 않았습니다. 다시 시도해 주세요.")
            return

        answer = ask_gpt(question_text)
        print(f"\n[GPT 답변]: {answer}\n")

        speak_text(answer)

    except Exception as e:
        print(f"❌ 실행 중 에러가 발생했습니다: {str(e)}")


if __name__ == "__main__":
    main()
# Out:
# 🎤 음성 녹음을 시작합니다... (5초간 말씀하세요)
# ✅ 녹음 완료: output/recorded.wav
# 🔍 음성을 텍스트로 변환하는 중 (STT)...
#
# [사용자 질문]:
# ⚠️ 음성이 제대로 감지되지 않았습니다. 다시 시도해 주세요.

# %% [markdown]
# ## 7. 이미지에 대해 설명하기

# %%
from openai import OpenAI
import requests


# 1. 위키미디어 이미지 다운로드 (User-Agent 헤더 추가로 차단 회피)
url = "https://tutorials.pytorch.kr/_images/transformer_architecture.jpg"
headers = {"User-Agent": "Mozilla/5.0"}
img_response = requests.get(url, headers=headers)

# 2. 이미지 바이너리를 Base64 문자열로 변환
base64_image = base64.b64encode(img_response.content).decode("utf-8")

# 3. Vision API 요청 (MIME 프리픽스 ...포함)
prompt = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해줘."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}"
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=prompt
)

print(response.choices[0].message.content)
# Out:
# 이 이미지는 Transformer 모델의 구조를 설명하고 있습니다. 왼쪽에는 인코더 부분이, 오른쪽에는 디코더 부분이 나타나 있으며, 각각 여러 개의 층을 포함하고 있습니다. 모든 층은 주의(attention) 메커니즘과 피드포워드 네트워크로 구성되어 있으며, 입력 및 출력 임베딩과 위치 인코딩을 포함합니다.

# %% [markdown]
# ## 8. 명함이미지 읽어오기

# %%
from openai import OpenAI
import base64  # 파이썬 표준 라이브러리


def encode_image(image_path):
    with open(image_path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")

image_base64 = encode_image("data/image/명함.png")  # 여기에 본인의 로컬 이미지 경로

data_url = f"data:image/png;base64,{image_base64}"

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "이미지의 글자 추출해 줄래"},
            {"type": "image_url", "image_url": {"url": data_url}},
        ],
    }]
)

print(response.choices[0].message.content)
# Out:
# 다음은 이미지에서 추출한 텍스트입니다:
#
# ```
# - 수협 명함 A형 -
#
# 홍 길 동
# 서울지점 / 지점장
#
# 123-456 서울특별시 00구 00로 서울빌딩
# Tel 02-2000-0000
# Fax 02-0000-0000
# phone 010-0000-0000
# www.suhyup.co.kr
# seoul@suhyup.com
# ```

# %% [markdown]
# # WIKIPEDIA

# %%
# uv add wikipediaapi

# %%
import wikipediaapi as wiki

page = wiki.page('인공지능')
