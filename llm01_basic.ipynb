# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(
    api_key = api_key
)

print(client.api_key)
# Out:
# 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

# %% [markdown]
# # COLAB에서 불러오기

# %% [markdown]
# colab > 열쇠 > 키 추가 > 노트북 액세스 활성화 >
#
# from openai import OpenAI
# import openai
# import os
# from google.colab import userdata
#
# OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
#
# client = OpenAI(api_key=OPENAI_API_KEY)
# completion = client.chat.completions.create(model='gpt-4o-mini', messages=[{'role':'user','content':'hello world'}])
#
# print(completion)
# print(completion.choices[0].message.content)
# print(completion.usage.completion_tokens)
# print(completion.usage.total_tokens)
#
#
# > 코드 입력

# %% [markdown]
# # API 호출

# %%
# GPT에게 첫 번째 질문을 보냅니다
response = client.chat.completions.create(
    model="gpt-4o-mini",          # 사용할 모델
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다. 최대한 길게 설명해주세요."},
        {"role": "user",   "content": "파인튜닝이 무엇인지 상세하게 자세히 설명해 주세요."}
    ],
    temperature=0.7,   # 창의성 수준 (0~2, 높을수록 다양한 답변)
    max_tokens=512,    # 최대 응답 길이
    stream=False       #  
)

# GPT의 답변만 뽑아서 출력
print(response.choices[0].message.content)
# Out:
# 파인튜닝(Fine-tuning)은 머신러닝과 딥러닝 분야에서 일반적으로 사용되는 기법으로, 사전 훈련된 모델(pre-trained model)을 특정 작업이나 데이터셋에 맞게 조정하는 과정을 의미합니다. 이 방법은 특히 대량의 데이터로 훈련된 모델을 활용하여 새로운 작업에 대한 성능을 향상시키고, 훈련 시간을 줄이며, 필요한 데이터의 양을 최소화하는 데 유용합니다.
#
# ### 파인튜닝의 배경
#
# 1. **사전 훈련된 모델**: 파인튜닝은 대부분 이미 대량의 데이터로 훈련된 모델을 기반으로 합니다. 예를 들어, 이미지 인식의 경우, ImageNet과 같은 대규모 이미지 데이터셋으로 훈련된 CNN(Convolutional Neural Network) 모델이 사전 훈련된 모델에 해당합니다. 이러한 모델은 일반적인 특징을 인식하는 데 뛰어난 성능을 보입니다.
#
# 2. **전이 학습(Transfer Learning)**: 파인튜닝은 전이 학습의 한 형태로 볼 수 있습니다. 전이 학습은 한 도메인에서 배운 지식을 다른 도메인에 적용하는 방법입니다. 예를 들어, 고양이와 개를 분류하는 데 특화된 모델을 개발할 때, 이미 학습한 고양이와 개에 대한 정보를 활용하여 다른 동물을 분류하는 데 사용할 수 있습니다.
#
# ### 파인튜닝의 과정
#
# 1. **모델 선택**: 특정 작업에 적합한 사전 훈련된 모델을 선택합니다. 예를 들어, 이미지 분류 작업에는 ResNet, VGG, EfficientNet과 같은 모델을 선택할 수 있습니다. 자연어 처리(NLP)에서는 BERT, GPT, T5와 같은 모델이 있습니다.
#
# 2. **데이터 준비**: 특정 작업에 맞는 데이터셋을 준비합니다. 이 데이터셋은 모델이 학습할 특정 특징이나 패턴을 포함해야 합니다.
#
# 3. **모델 수정**: 사전 훈련된 모델의 마지막 층(레이어)을 수정하여 새로운 클래스 수에 맞게 조정합니다. 예를 들어, 고양이와 개를 분류하는 모델을 10종의 동물을 분류하도록 수정할 수 있습니다.
#
# 4. **훈련**: 수정된 모델을 새로운 데이터셋

# %%
# GPT에게 첫 번째 질문을 보냅니다
response = client.chat.completions.create(
    model="gpt-4o-mini",          # 사용할 모델
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다. 최대한 길게 설명해주세요."},
        {"role": "user",   "content": "파인튜닝이 무엇인지 상세하게 자세히 설명해 주세요."}
    ],
    temperature=0.7,   # 창의성 수준 (0~2, 높을수록 다양한 답변)
    max_tokens=512,    # 최대 응답 길이
    stream = True      # 응답을 한자씩 해줌      /   stream=False   # default       /   response.chioces[0].message.content는 stream=False일 때만 사용 가능
)

# GPT의 답변만 뽑아서 출력
for c in response :
    if c.choices[0].delta.content :   # None이 출력이 안되도록 조건 지정
        print(c.choices[0].delta.content, end='')
# Out:
# 파인튜닝(Fine-Tuning)은 머신러닝, 특히 딥러닝 모델의 학습 과정에서 사용되는 기법으로, 이미 학습된 모델을 기반으로 특정한 작업이나 데이터셋에 맞게 조정하는 과정을 의미합니다. 이 방법은 주로 전이 학습(Transfer Learning)과 관련이 깊습니다. 전이 학습은 한 분야에서 학습한 지식을 다른 분야에 적용하는 개념으로, 파인튜닝은 그 구체적인 실행 방법 중 하나입니다.
#
# ### 파인튜닝의 과정
#
# 1. **사전 학습된 모델 선택**:
#    - 파인튜닝을 시작하기 위해서는 먼저 사전 학습된(pre-trained) 모델을 선택합니다. 이러한 모델은 대규모 데이터셋(예: ImageNet, COCO 등)에서 학습된 모델로, 일반적인 특징을 잘 인식할 수 있는 능력을 가지고 있습니다.
#
# 2. **데이터셋 준비**:
#    - 특정 작업에 맞는 데이터셋을 준비합니다. 예를 들어, 이미지 분류 작업을 위해 특정 클래스에 대한 이미지를 수집하거나, 자연어 처리(NLP) 작업을 위해 특정 도메인의 텍스트 데이터를 수집할 수 있습니다.
#
# 3. **모델 구조 조정**:
#    - 사전 학습된 모델의 마지막 레이어를 특정 작업에 맞게 조정합니다. 예를 들어, 일반적으로 분류 문제의 경우 마지막 레이어는 클래스 수에 맞게 조정됩니다. 이는 모델이 새로운 데이터셋에 대해 보다 적합한 예측을 할 수 있도록 돕습니다.
#
# 4. **파라미터 동결 및 조정**:
#    - 파인튜닝 과정에서는 일부 레이어의 파라미터를 '동결'하여 학습 중에 업데이트되지 않도록 할 수 있습니다. 일반적으로 초기 몇 개의 레이어는 이미 유용한 특징을 학습했기 때문에 동결하고, 마지막 몇 개의 레이어만 학습하는 것이 일반적입니다. 이렇게 하면 과적합(overfitting)을 방지하고 학습 시간을 단축할 수 있습니다.
#
# 5. **학습**:
#    - 준비된 데이터셋을 사용하여 모델을 학습합니다. 이 과정에서 적절한 학습률(learning rate)과 옵티마이저(optimizer)를 선택하는 것이 중요합니다. 초기에는 낮은 학습률을 사용

# %% [markdown]
# # n 은 답변 갯수

# %%
# GPT에게 첫 번째 질문을 보냅니다
response = client.chat.completions.create(
    model="gpt-4o-mini",          # 사용할 모델
    messages=[
        {"role": "system", "content": "당신은 친절한 AI 어시스턴트입니다. 친절하게 설명해주세요."},
        {"role": "user",   "content": "파인튜닝이 무엇인지 한줄로 설명해 주세요."}
    ],
    temperature=0.7,   # 창의성 수준 (0~2, 높을수록 다양한 답변)
    n=3,
    stream = False
)
print(response.choices[0].message.content)
print(response.choices[1].message.content)
print(response.choices[2].message.content)
# Out:
# 파인튜닝은 미리 학습된 모델을 특정 작업에 맞게 추가로 학습시켜 성능을 개선하는 과정입니다.
# 파인튜닝은 기존의 모델을 특정 작업이나 데이터에 맞게 추가 학습시켜 성능을 향상시키는 과정입니다.
# 파인튜닝은 이미 학습된 모델을 특정 작업에 맞게 추가로 학습시키는 과정을 말합니다.

# %%
# ① system 없이 질문
response_no_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.3,
    max_tokens=200,
)


print("─── system 없음 ───")
print(response_no_sys.choices[0].message.content)
# Out:
# ─── system 없음 ───
# 계약 해지 통보는 계약서에 명시된 해지 조건이나 절차에 따라 다릅니다. 일반적으로 다음과 같은 사항을 고려해야 합니다:
#
# 1. **계약서 확인**: 계약서에 해지 통보를 위한 특정 기간이나 절차가 명시되어 있는지 확인하세요. 보통 30일, 60일 등의 사전 통보 기간이 요구될 수 있습니다.
#
# 2. **법적 요건**: 특정 계약의 경우 법적으로 요구되는 해지 통보 기간이 있을 수 있습니다. 예를 들어, 임대차 계약이나 근로 계약 등은 관련 법률에 따라 규정이 있을 수 있습니다.
#
# 3. **상대방과의 관계**: 계약 해지 통보는 상대방과의 관계에 영향을 미칠 수 있으므로, 가능한 한 원만하게 진행하는 것이 좋습니다. 상대방에게 충분한 시간을 주는 것이 좋습니다.
#
# 4. **서면

# %%
# ② system 있이 질문
response_with_sys = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "당신은 대한민국 법률 전문가입니다. 관련 법조항을 인용하여 3문장 이내로 답변하세요."},
        {"role": "user",   "content": "계약 해지 통보는 언제 해야 하나요?"}
    ],
    temperature=0.3,
    max_tokens=200,
)


print("\n─── system 있음 ───")
print(response_with_sys.choices[0].message.content)
# Out:
# ─── system 있음 ───
# 계약 해지 통보는 계약서에 명시된 해지 통지 기간에 따라야 하며, 특별한 규정이 없을 경우 민법 제자 543조에 따라 상대방에게 해지 의사를 통지해야 합니다. 계약 해지의 경우, 통지 후 일정 기간이 지나야 해지가 유효하므로, 미리 충분한 시간을 두고 통보하는 것이 중요합니다. 따라서 계약서의 조건을 반드시 확인해야 합니다.

# %%
# 앞에서 받은 response 를 해부해봅니다
print("📝 답변 내용:")
print(response.choices[0].message.content)   # 실제 답변

print("\n🏁 종료 이유:", response.choices[0].finish_reason)  # stop / length

print("\n📊 토큰 사용량:")
print("   입력 토큰:", response.usage.prompt_tokens)
print("   출력 토큰:", response.usage.completion_tokens)
print("   전체 토큰:", response.usage.total_tokens)
# Out:
# 📝 답변 내용:
# 파인튜닝은 이미 학습된 모델을 특정 작업이나 데이터셋에 맞게 추가로 학습시켜 성능을 향상시키는 과정입니다.
#
# 🏁 종료 이유: stop
#
# 📊 토큰 사용량:
#    입력 토큰: 40
#    출력 토큰: 36
#    전체 토큰: 76

# %%
# 🧪 실험: max_tokens 를 너무 작게 하면 어떻게 될까?
response_short = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "대한민국 헌법의 기본 원리를 상세히 설명해 주세요."}
    ],
    max_tokens=20,   # 의도적으로 아주 짧게 설정
)

print("답변:", response_short.choices[0].message.content)
print("종료 이유:", response_short.choices[0].finish_reason)  # → "length"
print("→ 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.")
# Out:
# 답변: 대한민국 헌법의 기본 원리는 다음과 같이 요약할 수 있습니다:
#
# 1.
# 종료 이유: length
# → 문장이 중간에 잘렸습니다! max_tokens를 늘려야 합니다.

# %%
# 방금 호출한 API의 비용을 직접 계산해봅니다
INPUT_PRICE  = 0.15   # 입력: $0.15 / 100만 토큰
OUTPUT_PRICE = 0.60   # 출력: $0.60 / 100만 토큰

# 사용한 토큰 수 가져오기
input_tokens  = response.usage.prompt_tokens
output_tokens = response.usage.completion_tokens

# 비용 계산 (달러)
total_cost = (input_tokens * INPUT_PRICE + output_tokens * OUTPUT_PRICE) / 1_000_000

print(f"입력: {input_tokens}토큰 / 출력: {output_tokens}토큰")
print(f"이번 호출 비용: ${total_cost:.6f}  (약 {total_cost * 1400:.4f}원)")
print(f"1,000번 호출하면: 약 {total_cost * 1000 * 1400:.0f}원")
# Out:
# 입력: 40토큰 / 출력: 36토큰
# 이번 호출 비용: $0.000028  (약 0.0386원)
# 1,000번 호출하면: 약 39원

# %% [markdown]
# #  누적 비용 추적기 만들기

# %%
# 호출할 때마다 토큰과 비용을 쌓아주는 추적기
class TokenTracker:
    def __init__(self):
        self.total_input  = 0
        self.total_output = 0
        self.call_count   = 0

    def add(self, response):               # API 응답을 넣으면 자동으로 집계
        self.total_input  += response.usage.prompt_tokens
        self.total_output += response.usage.completion_tokens
        self.call_count   += 1

    def report(self):                      # 지금까지 쓴 비용 출력
        cost = (self.total_input * 0.15 + self.total_output * 0.60) / 1_000_000
        print(f"총 {self.call_count}회 호출 | 입력 {self.total_input} + 출력 {self.total_output} 토큰")
        print(f"누적 비용: ${cost:.4f} (약 {cost * 1400:.0f}원)")

# 사용법 예시
tracker = TokenTracker()
tracker.add(response)     # 아까 받은 응답 등록
tracker.report()          # 지금까지 쓴 비용 출력
# Out:
# 총 1회 호출 | 입력 40 + 출력 36 토큰
# 누적 비용: $0.0000 (약 0원)
