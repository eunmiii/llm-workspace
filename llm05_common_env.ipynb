# %% [markdown]
# ## raw SDK- openai

# %%
# basic.py
from common import OPENAI_MODEL, get_openai_client

# 1. raw SDK 클라이언트 생성 (.env에서 OPENAI_API_KEY 자동 검증)
client = get_openai_client()

# 2. OpenAI Chat Completions API 호출
response = client.chat.completions.create(
    model=OPENAI_MODEL,
    temperature=0,
    messages=[
        {"role": "user", "content": "인공지능에 대해 설명해줘"}
    ]
)

# 3. 응답 텍스트 출력
print(response.choices[0].message.content)
# Out:
# 인공지능(AI, Artificial Intelligence)은 컴퓨터 시스템이나 기계가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해, 언어 처리 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 여러 분야에서 활용되며, 크게 두 가지로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 인공지능으로, 예를 들어 음성 인식, 이미지 인식, 추천 시스템 등이 이에 해당합니다. 이러한 시스템은 특정한 문제를 해결하는 데 최적화되어 있지만, 일반적인 지능을 갖추고 있지는 않습니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 갖춘 인공지능으로, 다양한 문제를 이해하고 해결할 수 있는 능력을 지니고 있습니다. 현재로서는 강한 인공지능은 이론적인 개념에 가까우며, 실제로 구현된 사례는 없습니다.
#
# 인공지능의 주요 기술로는 머신러닝(Machine Learning), 딥러닝(Deep Learning), 자연어 처리(Natural Language Processing), 컴퓨터 비전(Computer Vision) 등이 있습니다. 머신러닝은 데이터에서 패턴을 학습하여 예측이나 결정을 내리는 기술이며, 딥러닝은 인공신경망을 활용한 머신러닝의 한 분야입니다.
#
# 인공지능은 의료, 금융, 제조업, 자율주행차, 고객 서비스 등 다양한 분야에서 혁신을 가져오고 있으며, 앞으로도 그 발전 가능성이 무궁무진합니다. 그러나 윤리적 문제, 일자리 대체, 데이터 프라이버시 등의 이슈도 함께 논의되고 있습니다.

# %% [markdown]
# ## raw SDK - gemini

# %%
from common import GEMINI_MODEL, get_genai_client

# 1. google-genai Client 생성
client = get_genai_client()

# 2. Gemini 모델 호출 (google-genai SDK 전용 메서드)
response = client.models.generate_content(
    model=GEMINI_MODEL,
    contents="인공지능에 대해 설명해줘",
)

# 3. 응답 텍스트 출력
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# 인공지능(AI, Artificial Intelligence)은 **컴퓨터나 기계가 인간처럼 생각하고, 학습하고, 추론하며, 문제를 해결하는 능력을 갖추도록 만드는 기술 분야**를 말합니다. 쉽게 말해, 기계가 인간의 지능적인 행동을 모방하거나 더 뛰어넘도록 하는 것을 목표로 합니다.
#
# 조금 더 자세히 설명해 드릴게요.
#
# ---
#
# ### 인공지능의 핵심 능력
#
# 인공지능은 다양한 기술과 개념을 포함하지만, 주로 다음과 같은 핵심 능력들을 통해 구현됩니다.
#
# 1.  **학습 (Learning):**
#     *   데이터를 분석하여 패턴을 찾고, 그 패턴을 기반으로 미래를 예측하거나 의사결정을 합니다.
#     *   가장 대표적인 분야가 **머신러닝(Machine Learning)**이며, 최근 각광받는 **딥러닝(Deep Learning)**은 머신러닝의 한 종류로, 인간 뇌의 신경망을 모방한 인공신경망을 사용하여 복잡한 패턴을 학습합니다.
#     *   *예시:* 스팸 메일 분류, 추천 시스템(넷플릭스, 유튜브), 얼굴 인식.
#
# 2.  **추론 및 문제 해결 (Reasoning & Problem Solving):**
#     *   주어진 정보를 바탕으로 논리적으로 판단하고, 최적의 해결책을 찾아냅니다.
#     *   *예시:* 체스나 바둑 같은 게임에서 최적의 수를 찾는 AI(알파고), 의료 진단.
#
# 3.  **인지 (Perception):**
#     *   시각(이미지, 비디오)이나 청각(음성)과 같은 감각 정보를 받아들이고 해석합니다.
#     *   *예시:* 자율주행차의 주변 환경 인식, 음성 비서(Siri, 빅스비)의 목소리 인식.
#
# 4.  **언어 이해 및 생성 (Language Understanding & Generation):**
#     *   인간의 언어를 이해하고, 그에 따라 적절한 언어를 생성하여 소통합니다.
#     *   **자연어 처리(Natural Language Processing, NLP)**라고 불리는 분야입니다.
#     *   *예시:* 번역기, 챗봇, 요약 기능, 글쓰기 AI.
#
# ---
#
# ### 인공지능의 종류 (지능 수준에 따라)
#
# 인공지능은 그 지능의 수준과 범위에 따라 크게 세 가지로 분류할 수 있습니다.
#
# 1.  **약한 인공지능 (Narrow AI / Weak AI):**
#     *   현재 우리가 접하는 대부분의 AI가 여기에 해당합니다.
#     *   특정하고 제한된 한 가지 작업을 수행하는 데 특화되어 있습니다.
#     *   예: 바둑을 두거나, 번역을 하거나, 음성을 인식하는 등 특정 분야에서는 인간을 능가할 수 있지만, 다른 분야의 문제 해결에는 한계가 있습니다.
#     *   *예시:* 알파고, Siri, 자율주행차.
#
# 2.  **강한 인공지능 (General AI / Strong AI):**
#     *   아직 실현되지 않은 가상의 AI입니다.
#     *   인간처럼 다양한 분야에서 학습하고, 추론하며, 이해하고, 계획할 수 있는 능력을 가집니다. 즉, 인간과 동일한 수준의 인지 능력을 갖습니다.
#     *   *예시:* SF 영화에 나오는, 인간처럼 사고하고 감정을 느끼는 로봇.
#
# 3.  **초인공지능 (Superintelligence):**
#     *   강한 인공지능을 넘어서, 인간의 모든 지적 능력을 훨씬 뛰어넘는 가상의 AI입니다.
#     *   *예시:* 인류 전체의 지적 능력을 합친 것보다 뛰어난 AI.
#
# ---
#
# ### 인공지능은 우리 삶에 어떻게 활용될까요?
#
# 인공지능은 이미 우리 삶의 많은 부분에 스며들어 있습니다.
#
# *   **음성 비서 및 챗봇:** Siri, Google Assistant, 챗GPT 등
# *   **추천 시스템:** 넷플릭스 영화 추천, 유튜브 동영상 추천, 온라인 쇼핑몰 상품 추천
# *   **자율주행:** 테슬라 등의 자율주행차 기술
# *   **의료 분야:** 질병 진단 보조, 신약 개발, 맞춤형 치료법 제안
# *   **금융 분야:** 사기 탐지, 주식 시장 예측, 신용 평가
# *   **산업 자동화:** 로봇 팔을 이용한 공장 자동화, 품질 검사
# *   **콘텐츠 생성:** 이미지, 글, 음악 등 다양한 콘텐츠 생성 (예: DALL-E, Midjourney)
# *   **보안:** 얼굴 인식, 지문 인식, 영상 감시 분석
#
# ---
#
# ### 인공지능의 중요성과 미래
#
# 인공지능은 데이터를 기반으로 엄청난 처리 능력과 학습 능력을 보여주며, 인간이 할 수 없거나 시간이 오래 걸리는 일들을 빠르고 정확하게 수행할 수 있습니다. 이는 생산성 향상, 새로운 서비스 창출, 복잡한 사회 문제 해결 등 다양한 긍정적인 변화를 가져올 잠재력을 가지고 있습니다.
#
# 물론, 일자리 감소, 윤리적 문제(편향된 학습, 책임 소재), 프라이버시 침해, 악용 가능성 등 해결해야 할 과제와 논의해야 할 부분도 많습니다.
#
# 인공지능은 단순한 기술을 넘어, 우리 사회와 문명을 근본적으로 변화시킬 가장 중요한 기술 중 하나로 빠르게 발전하고 있습니다.

# %% [markdown]
# ## langchain - openai

# %%
# basic.py
from common import get_chat

# 1. LangChain ChatOpenAI 객체 생성 (provider="openai" 전달)
gpt = get_chat(provider="openai", temperature=0)

# 2. LangChain 방식으로 호출
response = gpt.invoke("인공지능에 대해 설명해줘")

# 3. 결과 출력 (LangChain AIMessage 객체이므로 .content 사용 가능)
print(response.content)
# Out:
# 인공지능(AI, Artificial Intelligence)은 컴퓨터 시스템이나 기계가 인간의 지능을 모방하여 학습, 추론, 문제 해결, 이해, 언어 처리 등의 작업을 수행할 수 있도록 하는 기술입니다. 인공지능은 여러 분야에서 활용되며, 크게 두 가지로 나눌 수 있습니다.
#
# 1. **약한 인공지능(Weak AI)**: 특정 작업을 수행하도록 설계된 인공지능으로, 예를 들어 음성 인식, 이미지 인식, 추천 시스템 등이 있습니다. 이러한 시스템은 특정 문제를 해결하는 데 특화되어 있으며, 일반적인 지능을 갖추고 있지 않습니다.
#
# 2. **강한 인공지능(Strong AI)**: 인간과 유사한 수준의 지능을 갖춘 인공지능으로, 다양한 문제를 이해하고 해결할 수 있는 능력을 지니고 있습니다. 현재로서는 강한 인공지능은 이론적인 개념에 가까우며, 실제로 구현된 사례는 없습니다.
#
# 인공지능의 주요 기술로는 머신러닝(Machine Learning), 딥러닝(Deep Learning), 자연어 처리(Natural Language Processing), 컴퓨터 비전(Computer Vision) 등이 있습니다. 머신러닝은 데이터에서 패턴을 학습하여 예측이나 결정을 내리는 기술이며, 딥러닝은 인공신경망을 이용한 머신러닝의 한 분야로, 복잡한 데이터 처리에 강점을 보입니다.
#
# 인공지능은 의료, 금융, 제조, 자율주행차, 고객 서비스 등 다양한 분야에서 활용되고 있으며, 우리의 일상생활에 점점 더 많은 영향을 미치고 있습니다. 그러나 인공지능의 발전과 함께 윤리적, 사회적 문제도 제기되고 있어, 이에 대한 논의와 연구도 활발히 이루어지고 있습니다.

# %% [markdown]
# ## langchain - gemini

# %%
# basic.py
from common import get_chat

# 1. LangChain ChatOpenAI 객체 생성 (provider="openai" 전달)
gpt = get_chat(provider="gemini", temperature=0)

# 2. LangChain 방식으로 호출
response = gpt.invoke("인공지능에 대해 설명해줘")

# 3. 결과 출력 (LangChain AIMessage 객체이므로 .content 사용 가능)
print(response.content)
# Out:
# 인공지능(AI, Artificial Intelligence)은 **컴퓨터 시스템이 인간의 지능적인 작업을 모방하고 수행하도록 만드는 기술**을 말합니다. 쉽게 말해, 기계가 사람처럼 생각하고, 학습하고, 문제를 해결하고, 의사결정을 내리는 능력을 갖추도록 하는 것이죠.
#
# ### 인공지능의 핵심 개념
#
# 1.  **학습 (Learning):** AI는 데이터를 통해 학습합니다. 특정 패턴이나 규칙을 스스로 찾아내고, 이를 바탕으로 미래를 예측하거나 새로운 결정을 내립니다.
#     *   **머신러닝 (Machine Learning):** AI의 한 분야로, 명시적으로 프로그래밍하지 않고도 컴퓨터가 데이터로부터 학습할 수 있도록 하는 기술입니다.
#     *   **딥러닝 (Deep Learning):** 머신러닝의 한 종류로, 인간 뇌의 신경망 구조를 모방한 '인공신경망'을 사용하여 복잡한 패턴을 학습하고 인식하는 데 탁월한 성능을 보입니다. 이미지 인식, 음성 인식, 자연어 처리 등에서 혁혁한 성과를 내고 있습니다.
#
# 2.  **추론 (Reasoning):** 학습한 지식과 정보를 바탕으로 논리적인 결론을 도출합니다.
#
# 3.  **문제 해결 (Problem Solving):** 주어진 목표를 달성하기 위한 최적의 방법을 찾아냅니다.
#
# 4.  **지각 (Perception):** 카메라나 마이크 같은 센서를 통해 외부 환경을 인식하고 이해합니다. (예: 이미지 인식, 음성 인식)
#
# 5.  **자연어 처리 (Natural Language Processing, NLP):** 인간의 언어를 이해하고 생성하며, 번역하거나 요약하는 등의 작업을 수행합니다.
#
# ### 인공지능의 종류
#
# 인공지능은 그 능력 수준에 따라 크게 세 가지로 나눌 수 있습니다.
#
# 1.  **약인공지능 (Narrow AI / Weak AI):**
#     *   현재 우리가 접하는 대부분의 AI가 여기에 해당합니다.
#     *   특정하고 제한된 한 가지 작업만을 수행하도록 설계되었습니다.
#     *   예: 음성 비서(Siri, 빅스비), 바둑 AI(알파고), 추천 시스템(넷플릭스, 유튜브), 자율주행 자동차, 스팸 메일 필터링 등.
#     *   인간처럼 사고하거나 의식을 가지고 있지는 않습니다.
#
# 2.  **강인공지능 (General AI / Strong AI):**
#     *   아직은 이론적인 단계에 있으며, 인간처럼 다양한 지적 작업을 수행하고 학습하며, 추론하고 문제를 해결할 수 있는 능력을 가진 AI를 말합니다.
#     *   인간과 동등하거나 그 이상의 지능을 가질 것으로 예상됩니다.
#
# 3.  **초인공지능 (Super AI):**
#     *   강인공지능을 넘어, 인간의 모든 지적 능력을 훨씬 뛰어넘는 가상의 AI입니다.
#     *   SF 영화에서 자주 등장하는 개념입니다.
#
# ### 인공지능의 활용 분야 (예시)
#
# *   **음성 인식 및 비서:** 스마트폰 음성 비서, 스마트 스피커
# *   **이미지 및 영상 인식:** 얼굴 인식, 의료 영상 분석, 자율주행 자동차의 주변 환경 인식
# *   **자연어 처리:** 번역기, 챗봇, 문서 요약, 감성 분석
# *   **추천 시스템:** 온라인 쇼핑몰, OTT 서비스의 맞춤형 콘텐츠 추천
# *   **의료:** 질병 진단 보조, 신약 개발, 맞춤형 치료법 제안
# *   **금융:** 사기 탐지, 주식 시장 예측, 신용 평가
# *   **제조업:** 로봇 자동화, 품질 검사, 생산 효율 최적화
# *   **교육:** 맞춤형 학습 콘텐츠 제공, 학습 진도 관리
# *   **콘텐츠 생성:** 그림, 음악, 글 등 창작 활동 (생성형 AI)
#
# ### 인공지능의 중요성과 미래
#
# 인공지능은 우리 사회와 산업 전반에 걸쳐 혁신적인 변화를 가져오고 있으며, 앞으로 그 영향력은 더욱 커질 것입니다. 생산성 향상, 새로운 서비스 창출, 복잡한 문제 해결 등 긍정적인 측면이 많지만, 동시에 일자리 변화, 윤리적 문제, 개인 정보 보호 등 해결해야 할 과제들도 안고 있습니다.
#
# 결론적으로 인공지능은 **인간의 지능을 모방하여 다양한 작업을 수행하고, 데이터를 통해 스스로 학습하며 발전하는 컴퓨터 시스템**이라고 할 수 있습니다.
